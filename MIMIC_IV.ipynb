# %% [markdown]
# <a href="https://colab.research.google.com/github/areias/mimic-iv/blob/main/MIMIC_IV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# code to dowload the dataset
#https://physionet.org/content/mimic-iv-demo-omop/0.9/
# !wget -r -N -c -np https://physionet.org/files/mimic-iv-demo-omop/0.9/
# Out:
# Streaming output truncated to the last 5000 lines.
# Length: 489 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_987245.json’
#
# physionet.org/files 100%[===================>]     489  --.-KB/s    in 0s
#
# 2021-11-11 13:11:18 (83.3 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_987245.json’ saved [489/489]
#
# --2021-11-11 13:11:18--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_989878.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 535 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_989878.json’
#
# physionet.org/files 100%[===================>]     535  --.-KB/s    in 0s
#
# 2021-11-11 13:11:18 (76.0 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_989878.json’ saved [535/535]
#
# --2021-11-11 13:11:18--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_990499.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 534 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_990499.json’
#
# physionet.org/files 100%[===================>]     534  --.-KB/s    in 0s
#
# 2021-11-11 13:11:18 (86.8 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_990499.json’ saved [534/534]
#
# --2021-11-11 13:11:18--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_991710.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 534 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_991710.json’
#
# physionet.org/files 100%[===================>]     534  --.-KB/s    in 0s
#
# 2021-11-11 13:11:18 (86.9 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_991710.json’ saved [534/534]
#
# --2021-11-11 13:11:18--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_992956.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 533 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_992956.json’
#
# physionet.org/files 100%[===================>]     533  --.-KB/s    in 0s
#
# 2021-11-11 13:11:18 (95.8 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_992956.json’ saved [533/533]
#
# --2021-11-11 13:11:18--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_993631.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 534 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_993631.json’
#
# physionet.org/files 100%[===================>]     534  --.-KB/s    in 0s
#
# 2021-11-11 13:11:18 (52.6 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_993631.json’ saved [534/534]
#
# --2021-11-11 13:11:18--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_997881.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 482 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_997881.json’
#
# physionet.org/files 100%[===================>]     482  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (89.6 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_997881.json’ saved [482/482]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1113076.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 974 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1113076.json’
#
# physionet.org/files 100%[===================>]     974  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (167 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1113076.json’ saved [974/974]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1113079.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 934 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1113079.json’
#
# physionet.org/files 100%[===================>]     934  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (162 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1113079.json’ saved [934/934]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1113346.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 979 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1113346.json’
#
# physionet.org/files 100%[===================>]     979  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (142 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1113346.json’ saved [979/979]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1127433.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 985 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1127433.json’
#
# physionet.org/files 100%[===================>]     985  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (184 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1127433.json’ saved [985/985]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1167323.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 918 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1167323.json’
#
# physionet.org/files 100%[===================>]     918  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (168 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1167323.json’ saved [918/918]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1308251.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 923 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1308251.json’
#
# physionet.org/files 100%[===================>]     923  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (149 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1308251.json’ saved [923/923]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1309992.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 929 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1309992.json’
#
# physionet.org/files 100%[===================>]     929  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (151 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1309992.json’ saved [929/929]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1328689.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 918 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1328689.json’
#
# physionet.org/files 100%[===================>]     918  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (133 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1328689.json’ saved [918/918]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1332419.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 982 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1332419.json’
#
# physionet.org/files 100%[===================>]     982  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (262 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1332419.json’ saved [982/982]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1366754.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1009 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1366754.json’
#
# physionet.org/files 100%[===================>]    1009  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (315 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1366754.json’ saved [1009/1009]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1387458.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 928 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1387458.json’
#
# physionet.org/files 100%[===================>]     928  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (241 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1387458.json’ saved [928/928]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1396154.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 914 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1396154.json’
#
# physionet.org/files 100%[===================>]     914  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (187 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1396154.json’ saved [914/914]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1539407.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 914 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1539407.json’
#
# physionet.org/files 100%[===================>]     914  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (225 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1539407.json’ saved [914/914]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1539463.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 931 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1539463.json’
#
# physionet.org/files 100%[===================>]     931  --.-KB/s    in 0s
#
# 2021-11-11 13:11:19 (177 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1539463.json’ saved [931/931]
#
# --2021-11-11 13:11:19--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1545996.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 918 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1545996.json’
#
# physionet.org/files 100%[===================>]     918  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (234 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1545996.json’ saved [918/918]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1560525.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 985 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1560525.json’
#
# physionet.org/files 100%[===================>]     985  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (198 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1560525.json’ saved [985/985]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1560751.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1001 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1560751.json’
#
# physionet.org/files 100%[===================>]    1001  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (173 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1560751.json’ saved [1001/1001]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1592539.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 922 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1592539.json’
#
# physionet.org/files 100%[===================>]     922  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (270 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1592539.json’ saved [922/922]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593063.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 965 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593063.json’
#
# physionet.org/files 100%[===================>]     965  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (229 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593063.json’ saved [965/965]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593611.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 998 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593611.json’
#
# physionet.org/files 100%[===================>]     998  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (250 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593611.json’ saved [998/998]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593698.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 981 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593698.json’
#
# physionet.org/files 100%[===================>]     981  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (226 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593698.json’ saved [981/981]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593966.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 939 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593966.json’
#
# physionet.org/files 100%[===================>]     939  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (272 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593966.json’ saved [939/939]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593969.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 929 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593969.json’
#
# physionet.org/files 100%[===================>]     929  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (191 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1593969.json’ saved [929/929]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1596977.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 990 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1596977.json’
#
# physionet.org/files 100%[===================>]     990  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (237 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1596977.json’ saved [990/990]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1707346.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 965 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1707346.json’
#
# physionet.org/files 100%[===================>]     965  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (284 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1707346.json’ saved [965/965]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1707348.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 977 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1707348.json’
#
# physionet.org/files 100%[===================>]     977  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (222 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1707348.json’ saved [977/977]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1718696.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 919 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1718696.json’
#
# physionet.org/files 100%[===================>]     919  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (122 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1718696.json’ saved [919/919]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1718698.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 946 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1718698.json’
#
# physionet.org/files 100%[===================>]     946  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (159 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1718698.json’ saved [946/946]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1718752.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1008 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1718752.json’
#
# physionet.org/files 100%[===================>]    1008  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (210 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1718752.json’ saved [1008/1008]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1790982.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 965 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1790982.json’
#
# physionet.org/files 100%[===================>]     965  --.-KB/s    in 0s
#
# 2021-11-11 13:11:20 (139 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1790982.json’ saved [965/965]
#
# --2021-11-11 13:11:20--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1797515.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 913 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1797515.json’
#
# physionet.org/files 100%[===================>]     913  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (82.2 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1797515.json’ saved [913/913]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1836434.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 914 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1836434.json’
#
# physionet.org/files 100%[===================>]     914  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (130 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_1836434.json’ saved [914/914]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19016865.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 984 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19016865.json’
#
# physionet.org/files 100%[===================>]     984  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (186 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19016865.json’ saved [984/984]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019003.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 914 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019003.json’
#
# physionet.org/files 100%[===================>]     914  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (161 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019003.json’ saved [914/914]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019072.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 914 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019072.json’
#
# physionet.org/files 100%[===================>]     914  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (149 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019072.json’ saved [914/914]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019073.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 919 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019073.json’
#
# physionet.org/files 100%[===================>]     919  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (153 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019073.json’ saved [919/919]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019112.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 986 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019112.json’
#
# physionet.org/files 100%[===================>]     986  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (191 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019112.json’ saved [986/986]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019113.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 933 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019113.json’
#
# physionet.org/files 100%[===================>]     933  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (131 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019113.json’ saved [933/933]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019418.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 973 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019418.json’
#
# physionet.org/files 100%[===================>]     973  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (225 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019418.json’ saved [973/973]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019419.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 914 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019419.json’
#
# physionet.org/files 100%[===================>]     914  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (162 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19019419.json’ saved [914/914]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19020053.json
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 982 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19020053.json’
#
# physionet.org/files 100%[===================>]     982  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (133 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19020053.json’ saved [982/982]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19020131.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 978 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19020131.json’
#
# physionet.org/files 100%[===================>]     978  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (145 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19020131.json’ saved [978/978]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19035247.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 919 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19035247.json’
#
# physionet.org/files 100%[===================>]     919  --.-KB/s    in 0s
#
# 2021-11-11 13:11:21 (138 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19035247.json’ saved [919/919]
#
# --2021-11-11 13:11:21--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19036628.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 918 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19036628.json’
#
# physionet.org/files 100%[===================>]     918  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (192 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19036628.json’ saved [918/918]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19040187.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 979 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19040187.json’
#
# physionet.org/files 100%[===================>]     979  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (160 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19040187.json’ saved [979/979]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19041255.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 919 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19041255.json’
#
# physionet.org/files 100%[===================>]     919  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (130 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19041255.json’ saved [919/919]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19041287.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 978 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19041287.json’
#
# physionet.org/files 100%[===================>]     978  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (199 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19041287.json’ saved [978/978]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19041926.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 918 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19041926.json’
#
# physionet.org/files 100%[===================>]     918  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (116 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19041926.json’ saved [918/918]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19046742.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 965 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19046742.json’
#
# physionet.org/files 100%[===================>]     965  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (170 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19046742.json’ saved [965/965]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19049024.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 982 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19049024.json’
#
# physionet.org/files 100%[===================>]     982  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (177 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19049024.json’ saved [982/982]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19049684.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1002 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19049684.json’
#
# physionet.org/files 100%[===================>]    1002  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (140 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19049684.json’ saved [1002/1002]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19049686.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 993 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19049686.json’
#
# physionet.org/files 100%[===================>]     993  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (141 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19049686.json’ saved [993/993]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19057568.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 928 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19057568.json’
#
# physionet.org/files 100%[===================>]     928  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (153 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19057568.json’ saved [928/928]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19061089.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 918 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19061089.json’
#
# physionet.org/files 100%[===================>]     918  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (176 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19061089.json’ saved [918/918]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19065567.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 978 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19065567.json’
#
# physionet.org/files 100%[===================>]     978  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (164 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19065567.json’ saved [978/978]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19068781.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 927 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19068781.json’
#
# physionet.org/files 100%[===================>]     927  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (124 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19068781.json’ saved [927/927]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19071430.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 965 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19071430.json’
#
# physionet.org/files 100%[===================>]     965  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (147 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19071430.json’ saved [965/965]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19071700.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1029 (1.0K) [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19071700.json’
#
# physionet.org/files 100%[===================>]   1.00K  --.-KB/s    in 0s
#
# 2021-11-11 13:11:22 (158 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19071700.json’ saved [1029/1029]
#
# --2021-11-11 13:11:22--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19072176.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 992 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19072176.json’
#
# physionet.org/files 100%[===================>]     992  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (163 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19072176.json’ saved [992/992]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19072321.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 927 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19072321.json’
#
# physionet.org/files 100%[===================>]     927  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (129 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19072321.json’ saved [927/927]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19073712.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 928 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19073712.json’
#
# physionet.org/files 100%[===================>]     928  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (149 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19073712.json’ saved [928/928]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19073777.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 920 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19073777.json’
#
# physionet.org/files 100%[===================>]     920  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (150 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19073777.json’ saved [920/920]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19074247.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 974 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19074247.json’
#
# physionet.org/files 100%[===================>]     974  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (108 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19074247.json’ saved [974/974]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19074558.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 973 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19074558.json’
#
# physionet.org/files 100%[===================>]     973  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (204 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19074558.json’ saved [973/973]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19075380.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 982 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19075380.json’
#
# physionet.org/files 100%[===================>]     982  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (145 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19075380.json’ saved [982/982]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19075601.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 914 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19075601.json’
#
# physionet.org/files 100%[===================>]     914  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (88.6 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19075601.json’ saved [914/914]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19076492.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 916 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19076492.json’
#
# physionet.org/files 100%[===================>]     916  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (145 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19076492.json’ saved [916/916]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077241.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 965 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077241.json’
#
# physionet.org/files 100%[===================>]     965  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (175 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077241.json’ saved [965/965]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077513.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 927 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077513.json’
#
# physionet.org/files 100%[===================>]     927  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (166 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077513.json’ saved [927/927]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077546.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 975 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077546.json’
#
# physionet.org/files 100%[===================>]     975  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (148 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077546.json’ saved [975/975]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077547.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 914 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077547.json’
#
# physionet.org/files 100%[===================>]     914  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (143 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077547.json’ saved [914/914]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077548.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 914 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077548.json’
#
# physionet.org/files 100%[===================>]     914  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (256 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077548.json’ saved [914/914]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077763.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 931 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077763.json’
#
# physionet.org/files 100%[===================>]     931  --.-KB/s    in 0s
#
# 2021-11-11 13:11:23 (217 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19077763.json’ saved [931/931]
#
# --2021-11-11 13:11:23--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19078557.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1004 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19078557.json’
#
# physionet.org/files 100%[===================>]    1004  --.-KB/s    in 0s
#
# 2021-11-11 13:11:24 (217 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19078557.json’ saved [1004/1004]
#
# --2021-11-11 13:11:24--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19078921.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 923 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19078921.json’
#
# physionet.org/files 100%[===================>]     923  --.-KB/s    in 0s
#
# 2021-11-11 13:11:24 (257 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19078921.json’ saved [923/923]
#
# --2021-11-11 13:11:24--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19078924.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 924 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19078924.json’
#
# physionet.org/files 100%[===================>]     924  --.-KB/s    in 0s
#
# 2021-11-11 13:11:24 (136 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19078924.json’ saved [924/924]
#
# --2021-11-11 13:11:24--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19079119.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 913 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19079119.json’
#
# physionet.org/files 100%[===================>]     913  --.-KB/s    in 0s
#
# 2021-11-11 13:11:24 (147 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19079119.json’ saved [913/913]
#
# --2021-11-11 13:11:24--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19079322.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 991 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19079322.json’
#
# physionet.org/files 100%[===================>]     991  --.-KB/s    in 0s
#
# 2021-11-11 13:11:24 (132 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19079322.json’ saved [991/991]
#
# --2021-11-11 13:11:24--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19079658.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 920 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19079658.json’
#
# physionet.org/files 100%[===================>]     920  --.-KB/s    in 0s
#
# 2021-11-11 13:11:24 (256 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugs/drug_19079658.json’ saved [920/920]
#
# ...
#
# --2021-11-11 13:11:51--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_0.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 551 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_0.json’
#
# physionet.org/files 100%[===================>]     551  --.-KB/s    in 0s
#
# 2021-11-11 13:11:51 (96.8 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_0.json’ saved [551/551]
#
# --2021-11-11 13:11:51--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_262.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 507 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_262.json’
#
# physionet.org/files 100%[===================>]     507  --.-KB/s    in 0s
#
# 2021-11-11 13:11:51 (73.7 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_262.json’ saved [507/507]
#
# --2021-11-11 13:11:51--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_32037.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 552 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_32037.json’
#
# physionet.org/files 100%[===================>]     552  --.-KB/s    in 0s
#
# 2021-11-11 13:11:51 (98.2 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_32037.json’ saved [552/552]
#
# --2021-11-11 13:11:51--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_38004207.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 501 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_38004207.json’
#
# physionet.org/files 100%[===================>]     501  --.-KB/s    in 0s
#
# 2021-11-11 13:11:51 (49.9 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_38004207.json’ saved [501/501]
#
# --2021-11-11 13:11:51--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_38004515.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 552 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_38004515.json’
#
# physionet.org/files 100%[===================>]     552  --.-KB/s    in 0s
#
# 2021-11-11 13:11:51 (83.4 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_38004515.json’ saved [552/552]
#
# --2021-11-11 13:11:51--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_40481392.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 552 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_40481392.json’
#
# physionet.org/files 100%[===================>]     552  --.-KB/s    in 0s
#
# 2021-11-11 13:11:51 (83.9 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_40481392.json’ saved [552/552]
#
# --2021-11-11 13:11:51--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4134563.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 551 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4134563.json’
#
# physionet.org/files 100%[===================>]     551  --.-KB/s    in 0s
#
# 2021-11-11 13:11:51 (111 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4134563.json’ saved [551/551]
#
# --2021-11-11 13:11:51--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4147091.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 507 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4147091.json’
#
# physionet.org/files 100%[===================>]     507  --.-KB/s    in 0s
#
# 2021-11-11 13:11:51 (82.5 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4147091.json’ saved [507/507]
#
# --2021-11-11 13:11:51--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4147111.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 509 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4147111.json’
#
# physionet.org/files 100%[===================>]     509  --.-KB/s    in 0s
#
# 2021-11-11 13:11:52 (88.8 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4147111.json’ saved [509/509]
#
# --2021-11-11 13:11:52--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4148511.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 505 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4148511.json’
#
# physionet.org/files 100%[===================>]     505  --.-KB/s    in 0s
#
# 2021-11-11 13:11:52 (82.0 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4148511.json’ saved [505/505]
#
# --2021-11-11 13:11:52--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4149943.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 552 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4149943.json’
#
# physionet.org/files 100%[===================>]     552  --.-KB/s    in 0s
#
# 2021-11-11 13:11:52 (94.4 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4149943.json’ saved [552/552]
#
# --2021-11-11 13:11:52--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4149946.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 503 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4149946.json’
#
# physionet.org/files 100%[===================>]     503  --.-KB/s    in 0s
#
# 2021-11-11 13:11:52 (93.9 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4149946.json’ saved [503/503]
#
# --2021-11-11 13:11:52--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4150070.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 552 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4150070.json’
#
# physionet.org/files 100%[===================>]     552  --.-KB/s    in 0s
#
# 2021-11-11 13:11:52 (124 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4150070.json’ saved [552/552]
#
# --2021-11-11 13:11:52--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4150076.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 503 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4150076.json’
#
# physionet.org/files 100%[===================>]     503  --.-KB/s    in 0s
#
# 2021-11-11 13:11:52 (105 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4150076.json’ saved [503/503]
#
# --2021-11-11 13:11:52--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4150086.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 503 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4150086.json’
#
# physionet.org/files 100%[===================>]     503  --.-KB/s    in 0s
#
# 2021-11-11 13:11:52 (85.9 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4150086.json’ saved [503/503]
#
# --2021-11-11 13:11:52--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4160026.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 552 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4160026.json’
#
# physionet.org/files 100%[===================>]     552  --.-KB/s    in 0s
#
# 2021-11-11 13:11:52 (91.2 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4160026.json’ saved [552/552]
#
# --2021-11-11 13:11:52--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4305366.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 552 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4305366.json’
#
# physionet.org/files 100%[===================>]     552  --.-KB/s    in 0s
#
# 2021-11-11 13:11:52 (109 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_4305366.json’ saved [552/552]
#
# --2021-11-11 13:11:52--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_581383.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 505 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_581383.json’
#
# physionet.org/files 100%[===================>]     505  --.-KB/s    in 0s
#
# 2021-11-11 13:11:52 (74.7 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_581383.json’ saved [505/505]
#
# --2021-11-11 13:11:52--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_581385.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 552 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_581385.json’
#
# physionet.org/files 100%[===================>]     552  --.-KB/s    in 0s
#
# 2021-11-11 13:11:52 (84.3 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_581385.json’ saved [552/552]
#
# --2021-11-11 13:11:52--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_763903.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 552 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_763903.json’
#
# physionet.org/files 100%[===================>]     552  --.-KB/s    in 0s
#
# 2021-11-11 13:11:52 (98.2 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_763903.json’ saved [552/552]
#
# --2021-11-11 13:11:52--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_8870.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 552 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_8870.json’
#
# physionet.org/files 100%[===================>]     552  --.-KB/s    in 0s
#
# 2021-11-11 13:11:53 (92.7 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visitdetail/visitdetail_8870.json’ saved [552/552]
#
# --2021-11-11 13:11:53--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_262.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 547 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_262.json’
#
# physionet.org/files 100%[===================>]     547  --.-KB/s    in 0s
#
# 2021-11-11 13:11:53 (94.3 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_262.json’ saved [547/547]
#
# --2021-11-11 13:11:53--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_38004207.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 544 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_38004207.json’
#
# physionet.org/files 100%[===================>]     544  --.-KB/s    in 0s
#
# 2021-11-11 13:11:53 (82.9 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_38004207.json’ saved [544/544]
#
# --2021-11-11 13:11:53--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_581385.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 546 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_581385.json’
#
# physionet.org/files 100%[===================>]     546  --.-KB/s    in 0s
#
# 2021-11-11 13:11:53 (90.8 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_581385.json’ saved [546/546]
#
# --2021-11-11 13:11:53--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_8870.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 547 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_8870.json’
#
# physionet.org/files 100%[===================>]     547  --.-KB/s    in 0s
#
# 2021-11-11 13:11:53 (108 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_8870.json’ saved [547/547]
#
# --2021-11-11 13:11:53--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_8883.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 545 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_8883.json’
#
# physionet.org/files 100%[===================>]     545  --.-KB/s    in 0s
#
# 2021-11-11 13:11:53 (103 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_8883.json’ saved [545/545]
#
# --2021-11-11 13:11:53--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_9201.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 500 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_9201.json’
#
# physionet.org/files 100%[===================>]     500  --.-KB/s    in 0s
#
# 2021-11-11 13:11:53 (101 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/visits/visit_9201.json’ saved [500/500]
#
# FINISHED --2021-11-11 13:11:53--
# Total wall clock time: 1m 11s
# Downloaded: 953 files, 73M in 4.1s (17.8 MB/s)

# %% [markdown]
# # MIMIC-IV

# %% [markdown]
# ## 2b_concept.csv

# %% [markdown]
# https://doi.org/10.1101/2020.08.14.20175141

# %%
import pandas as pd

# %%
path = "physionet.org/files/mimic-iv-demo-omop/0.9/1_omop_data_csv/"

# %%
df = pd.read_csv(path+"2b_concept.csv")

# %%
df.head()
# Out:
#    concept_id                     concept_name  ... valid_end_DATE invalid_reason
# 0  2000011360       Caffeine Citrate 1 Syringe  ...     2099-12-31            NaN
# 1  2000010536                    Acetaminophen  ...     2099-12-31            NaN
# 2  2000011213                   Melatonin 1 MG  ...     2099-12-31            NaN
# 3  2000011355  0.9% Sodium Chloride 100 mL Bag  ...     2099-12-31            NaN
# 4  2000010313                       Vancomycin  ...     2099-12-31            NaN
#
# [5 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['concept_id', 'concept_name', 'domain_id', 'vocabulary_id',
#        'concept_class_id', 'standard_concept', 'concept_code',
#        'valid_start_DATE', 'valid_end_DATE', 'invalid_reason'],
#       dtype='object')

# %%
df.shape
# Out:
# (3885, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3885 entries, 0 to 3884
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   concept_id        3885 non-null   int64
#  1   concept_name      3885 non-null   object
#  2   domain_id         3885 non-null   object
#  3   vocabulary_id     3885 non-null   object
#  4   concept_class_id  3885 non-null   object
#  5   standard_concept  51 non-null     object
#  6   concept_code      3885 non-null   object
#  7   valid_start_DATE  3885 non-null   object
#  8   valid_end_DATE    3885 non-null   object
#  9   invalid_reason    0 non-null      float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 303.6+ KB

# %%
df.describe(include='all').T
# Out:
#                  count unique  ...          75%       max
# concept_id        3885    NaN  ...  2.00002e+09  2.11e+09
# concept_name      3885   3409  ...          NaN       NaN
# domain_id         3885     15  ...          NaN       NaN
# vocabulary_id     3885     28  ...          NaN       NaN
# concept_class_id  3885     21  ...          NaN       NaN
# standard_concept    51      1  ...          NaN       NaN
# concept_code      3885   3825  ...          NaN       NaN
# valid_start_DATE  3885      1  ...          NaN       NaN
# valid_end_DATE    3885      1  ...          NaN       NaN
# invalid_reason       0    NaN  ...          NaN       NaN
#
# [10 rows x 11 columns]

# %%
df['concept_name'].value_counts()
# Out:
# mesalamine                                                                      13
# Budesonide 0.16 MG/ACTUAT / formoterol fumarate 0.0045 MG/ACTUAT [Symbicort]     9
# Lidocaine                                                                        9
# Dutasteride 0.5 MG [Avodart]                                                     9
# Fentanyl                                                                         8
#                                                                                 ..
# Tunneled (Hickman) Dressing Change                                               1
# AMPUTATION FOR CIRCULATORY SYSTEM DISORDERS EXCEPT UPPER LIMB & TOE              1
# ASPERGILLUS SP. NOT FUMIGATUS, FLAVUS OR NIGER                                   1
# CANDIDA ALBICANS                                                                 1
# OTHER RESP SYSTEM O.R. PROCEDURES W/O CC/MCC                                     1
# Name: concept_name, Length: 3409, dtype: int64

# %%
df['domain_id'].value_counts()
# Out:
# Drug            1400
# Observation     1332
# Measurement      507
# Procedure        246
# Route             96
# Specimen          81
# Unit              58
# Visit             53
# Condition         34
# Meas Value        30
# Metadata          28
# Type Concept       9
# Race               7
# Device             3
# Ethnicity          1
# Name: domain_id, dtype: int64

# %%
df['concept_class_id'].value_counts()
# Out:
# Prescription Drug       1400
# MS-DRG                   916
# Organism                 364
# Lab Test                 280
# Procedure                278
# Clinical Observation     214
# Qualifier Value           97
# Specimen                  81
# Unit                      58
# Visit                     53
# Location                  36
# Clinical Finding          32
# Answer                    29
# Vocabulary                27
# Race                       7
# Meas Type                  6
# Observable Entity          2
# Drug Type                  2
# Visit Type                 1
# Domain                     1
# Ethnicity                  1
# Name: concept_class_id, dtype: int64

# %%
df['standard_concept'].value_counts()
# Out:
# S    51
# Name: standard_concept, dtype: int64

# %%
df['concept_code'].value_counts()
# Out:
# Odysseus generated                                                27
# SA (Sinus Arrhythmia)                                              3
# RBBB (Right Bundle Branch Block)                                   3
# LBBB (Left Bundle Branch Block)                                    3
# SVT (Supra Ventricular Tachycardia)                                3
#                                                                   ..
# Synarel nasal spray 1                                              1
# Leflunomide 10 mg                                                  1
# NON-BACTERIAL INFECT OF NERVOUS SYS EXC VIRAL MENINGITIS W MCC     1
# PNEUMOTHORAX W MCC                                                 1
# OTHER RESP SYSTEM O.R. PROCEDURES W/O CC/MCC                       1
# Name: concept_code, Length: 3825, dtype: int64

# %%
df.loc[df['concept_class_id']=="Race","concept_name"].value_counts()
# Out:
# ASIAN                            1
# UNABLE TO OBTAIN                 1
# BLACK/AFRICAN AMERICAN           1
# WHITE                            1
# AMERICAN INDIAN/ALASKA NATIVE    1
# UNKNOWN                          1
# OTHER                            1
# Name: concept_name, dtype: int64

# %% [markdown]
# ## person.csv

# %%
df = pd.read_csv(path+"person.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   person_id                    100 non-null    int64
#  1   gender_concept_id            100 non-null    int64
#  2   year_of_birth                100 non-null    int64
#  3   month_of_birth               0 non-null      float64
#  4   day_of_birth                 0 non-null      float64
#  5   birth_datetime               0 non-null      float64
#  6   race_concept_id              100 non-null    int64
#  7   ethnicity_concept_id         100 non-null    int64
#  8   location_id                  0 non-null      float64
#  9   provider_id                  0 non-null      float64
#  10  care_site_id                 0 non-null      float64
#  11  person_source_value          100 non-null    int64
#  12  gender_source_value          100 non-null    object
#  13  gender_source_concept_id     100 non-null    int64
#  14  race_source_value            95 non-null     object
#  15  race_source_concept_id       100 non-null    int64
#  16  ethnicity_source_value       5 non-null      object
#  17  ethnicity_source_concept_id  100 non-null    int64
# dtypes: float64(6), int64(9), object(3)
# memory usage: 14.2+ KB

# %%
df.describe(include='all').T
# Out:
#                             count unique  ...          75%          max
# person_id                     100    NaN  ...  4.38867e+18  8.80548e+18
# gender_concept_id             100    NaN  ...         8532         8532
# year_of_birth                 100    NaN  ...      2111.75         2149
# month_of_birth                  0    NaN  ...          NaN          NaN
# day_of_birth                    0    NaN  ...          NaN          NaN
# birth_datetime                  0    NaN  ...          NaN          NaN
# race_concept_id               100    NaN  ...         8527        2e+09
# ethnicity_concept_id          100    NaN  ...            0  3.80036e+07
# location_id                     0    NaN  ...          NaN          NaN
# provider_id                     0    NaN  ...          NaN          NaN
# care_site_id                    0    NaN  ...          NaN          NaN
# person_source_value           100    NaN  ...  1.00255e+07    1.004e+07
# gender_source_value           100      2  ...          NaN          NaN
# gender_source_concept_id      100    NaN  ...            0            0
# race_source_value              95      5  ...          NaN          NaN
# race_source_concept_id        100    NaN  ...        2e+09        2e+09
# ethnicity_source_value          5      1  ...          NaN          NaN
# ethnicity_source_concept_id   100    NaN  ...            0        2e+09
#
# [18 rows x 11 columns]
