# %% [markdown]
# <a href="https://colab.research.google.com/github/areias/mimic-iv/blob/main/MIMIC_IV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls sample_data
# Out:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
# code to dowload the dataset
#https://physionet.org/content/mimic-iv-demo-omop/0.9/
# !wget -r -N -c -np https://physionet.org/files/mimic-iv-demo-omop/0.9/
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Length: 489 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_987245.json’
#
# physionet.org/files 100%[===================>]     489  --.-KB/s    in 0s
#
# 2021-11-11 13:34:54 (70.0 MB/s) - ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_987245.json’ saved [489/489]
#
# --2021-11-11 13:34:54--  https://physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_989878.json
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 535 [application/json]
# Saving to: ‘physionet.org/files/mimic-iv-demo-omop/0.9/2_achilles_json/drugeras/drug_989878.json’
#
# physionet.org/files 100%[===================>]     535  --.-KB/s    in 0s
#
# ...

# %% [markdown]
# # MIMIC-IV

# %% [markdown]
# ## 2b_concept.csv

# %% [markdown]
# https://doi.org/10.1101/2020.08.14.20175141

# %%
import pandas as pd

# %%
path = "physionet.org/files/mimic-iv-demo-omop/0.9/1_omop_data_csv/"

# %%
df = pd.read_csv(path+"2b_concept.csv")

# %%
df.head()
# Out:
#    concept_id                     concept_name  ... valid_end_DATE invalid_reason
# 0  2000011360       Caffeine Citrate 1 Syringe  ...     2099-12-31            NaN
# 1  2000010536                    Acetaminophen  ...     2099-12-31            NaN
# 2  2000011213                   Melatonin 1 MG  ...     2099-12-31            NaN
# 3  2000011355  0.9% Sodium Chloride 100 mL Bag  ...     2099-12-31            NaN
# 4  2000010313                       Vancomycin  ...     2099-12-31            NaN
#
# [5 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['concept_id', 'concept_name', 'domain_id', 'vocabulary_id',
#        'concept_class_id', 'standard_concept', 'concept_code',
#        'valid_start_DATE', 'valid_end_DATE', 'invalid_reason'],
#       dtype='object')

# %%
df.shape
# Out:
# (3885, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3885 entries, 0 to 3884
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   concept_id        3885 non-null   int64
#  1   concept_name      3885 non-null   object
#  2   domain_id         3885 non-null   object
#  3   vocabulary_id     3885 non-null   object
#  4   concept_class_id  3885 non-null   object
#  5   standard_concept  51 non-null     object
#  6   concept_code      3885 non-null   object
#  7   valid_start_DATE  3885 non-null   object
#  8   valid_end_DATE    3885 non-null   object
#  9   invalid_reason    0 non-null      float64
# dtypes: float64(1), int64(1), object(8)
# memory usage: 303.6+ KB

# %%
df.describe(include='all').T
# Out:
#                  count unique  ...          75%       max
# concept_id        3885    NaN  ...  2.00002e+09  2.11e+09
# concept_name      3885   3409  ...          NaN       NaN
# domain_id         3885     15  ...          NaN       NaN
# vocabulary_id     3885     28  ...          NaN       NaN
# concept_class_id  3885     21  ...          NaN       NaN
# standard_concept    51      1  ...          NaN       NaN
# concept_code      3885   3825  ...          NaN       NaN
# valid_start_DATE  3885      1  ...          NaN       NaN
# valid_end_DATE    3885      1  ...          NaN       NaN
# invalid_reason       0    NaN  ...          NaN       NaN
#
# [10 rows x 11 columns]

# %%
df['concept_name'].value_counts()
# Out:
# mesalamine                                                                      13
# Dutasteride 0.5 MG [Avodart]                                                     9
# Budesonide 0.16 MG/ACTUAT / formoterol fumarate 0.0045 MG/ACTUAT [Symbicort]     9
# Lidocaine                                                                        9
# Vancomycin                                                                       8
#                                                                                 ..
# CORONARY BYPASS W PTCA W MCC                                                     1
# POSTPARTUM & POST ABORTION DIAGNOSES W O.R. PROCEDURE                            1
# BETA STREPTOCOCCI, NOT GROUP A                                                   1
# INFECTIONS, FEMALE REPRODUCTIVE SYSTEM W CC                                      1
# DIRECT EMER.                                                                     1
# Name: concept_name, Length: 3409, dtype: int64

# %%
df['domain_id'].value_counts()
# Out:
# Drug            1400
# Observation     1332
# Measurement      507
# Procedure        246
# Route             96
# Specimen          81
# Unit              58
# Visit             53
# Condition         34
# Meas Value        30
# Metadata          28
# Type Concept       9
# Race               7
# Device             3
# Ethnicity          1
# Name: domain_id, dtype: int64

# %%
df['concept_class_id'].value_counts()
# Out:
# Prescription Drug       1400
# MS-DRG                   916
# Organism                 364
# Lab Test                 280
# Procedure                278
# Clinical Observation     214
# Qualifier Value           97
# Specimen                  81
# Unit                      58
# Visit                     53
# Location                  36
# Clinical Finding          32
# Answer                    29
# Vocabulary                27
# Race                       7
# Meas Type                  6
# Observable Entity          2
# Drug Type                  2
# Ethnicity                  1
# Domain                     1
# Visit Type                 1
# Name: concept_class_id, dtype: int64

# %%
df['standard_concept'].value_counts()
# Out:
# S    51
# Name: standard_concept, dtype: int64

# %%
df['concept_code'].value_counts()
# Out:
# Odysseus generated                                         27
# SVT (Supra Ventricular Tachycardia)                         3
# SB (Sinus Bradycardia)                                      3
# A Flut (Atrial Flutter)                                     3
# RBBB (Right Bundle Branch Block)                            3
#                                                            ..
# Symbicort 160 mcg-4.5 mcg/actuation HFA Aerosol Inhaler     1
# 220074                                                      1
# 80023                                                       1
# MAJOR BLADDER PROCEDURES W CC                               1
# DIRECT EMER.                                                1
# Name: concept_code, Length: 3825, dtype: int64

# %%
df.loc[df['concept_class_id']=="Race","concept_name"].value_counts()
# Out:
# OTHER                            1
# WHITE                            1
# BLACK/AFRICAN AMERICAN           1
# UNKNOWN                          1
# ASIAN                            1
# AMERICAN INDIAN/ALASKA NATIVE    1
# UNABLE TO OBTAIN                 1
# Name: concept_name, dtype: int64

# %% [markdown]
# ## person.csv

# %%
df = pd.read_csv(path+"person.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   person_id                    100 non-null    int64
#  1   gender_concept_id            100 non-null    int64
#  2   year_of_birth                100 non-null    int64
#  3   month_of_birth               0 non-null      float64
#  4   day_of_birth                 0 non-null      float64
#  5   birth_datetime               0 non-null      float64
#  6   race_concept_id              100 non-null    int64
#  7   ethnicity_concept_id         100 non-null    int64
#  8   location_id                  0 non-null      float64
#  9   provider_id                  0 non-null      float64
#  10  care_site_id                 0 non-null      float64
#  11  person_source_value          100 non-null    int64
#  12  gender_source_value          100 non-null    object
# ...

# %%
df.describe(include='all').T
# Out:
#                             count unique  ...          75%          max
# person_id                     100    NaN  ...  4.38867e+18  8.80548e+18
# gender_concept_id             100    NaN  ...         8532         8532
# year_of_birth                 100    NaN  ...      2111.75         2149
# month_of_birth                  0    NaN  ...          NaN          NaN
# day_of_birth                    0    NaN  ...          NaN          NaN
# birth_datetime                  0    NaN  ...          NaN          NaN
# race_concept_id               100    NaN  ...         8527        2e+09
# ethnicity_concept_id          100    NaN  ...            0  3.80036e+07
# location_id                     0    NaN  ...          NaN          NaN
# provider_id                     0    NaN  ...          NaN          NaN
# care_site_id                    0    NaN  ...          NaN          NaN
# person_source_value           100    NaN  ...  1.00255e+07    1.004e+07
# ...

# %% [markdown]
# ## Observation:

# %%
df = pd.read_csv(path+"observation.csv")

# %%
df.head()
# Out:
#         observation_id  ...  qualifier_source_value
# 0 -7221215846302395378  ...                     NaN
# 1 -9113461341871004757  ...                     NaN
# 2 -6378179537712623650  ...                     NaN
# 3 -3000731179192887483  ...                     NaN
# 4 -8633553265894813739  ...                     NaN
#
# [5 rows x 18 columns]

# %%
df.shape
# Out:
# (31390, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31390 entries, 0 to 31389
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   observation_id                 31390 non-null  int64
#  1   person_id                      31390 non-null  int64
#  2   observation_concept_id         31390 non-null  int64
#  3   observation_date               31390 non-null  object
#  4   observation_datetime           31390 non-null  object
#  5   observation_type_concept_id    31390 non-null  int64
#  6   value_as_number                3281 non-null   float64
#  7   value_as_string                27049 non-null  object
#  8   value_as_concept_id            27049 non-null  float64
#  9   qualifier_concept_id           0 non-null      float64
#  10  unit_concept_id                0 non-null      float64
#  11  provider_id                    0 non-null      float64
# ...

# %%
df.describe(include='all').T
# Out:
#                                count unique  ...          75%          max
# observation_id                 31390    NaN  ...  4.54339e+18  9.22297e+18
# person_id                      31390    NaN  ...  4.66834e+18  8.80548e+18
# observation_concept_id         31390    NaN  ...  4.33726e+06  4.62741e+07
# observation_date               31390    863  ...          NaN          NaN
# observation_datetime           31390  10103  ...          NaN          NaN
# observation_type_concept_id    31390    NaN  ...        32817        32856
# value_as_number                 3281    NaN  ...            3          129
# value_as_string                27049    349  ...          NaN          NaN
# value_as_concept_id            27049    NaN  ...            0  4.58851e+07
# qualifier_concept_id               0    NaN  ...          NaN          NaN
# unit_concept_id                    0    NaN  ...          NaN          NaN
# ...

# %% [markdown]
# ## Specimen

# %%
df = pd.read_csv(path+"specimen.csv")

# %%
df.head()
# Out:
#            specimen_id  ...  disease_status_source_value
# 0 -5102033398575528989  ...                          NaN
# 1  5035924384215166531  ...                          NaN
# 2  4680974717267536012  ...                          NaN
# 3  1036293910445291253  ...                          NaN
# 4  4665676571104609028  ...                          NaN
#
# [5 rows x 15 columns]

# %%
df.shape
# Out:
# (150, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   specimen_id                  150 non-null    int64
#  1   person_id                    150 non-null    int64
#  2   specimen_concept_id          150 non-null    int64
#  3   specimen_type_concept_id     150 non-null    int64
#  4   specimen_date                150 non-null    object
#  5   specimen_datetime            150 non-null    object
#  6   quantity                     0 non-null      float64
#  7   unit_concept_id              0 non-null      float64
#  8   anatomic_site_concept_id     150 non-null    int64
#  9   disease_status_concept_id    150 non-null    int64
#  10  specimen_source_id           150 non-null    object
#  11  specimen_source_value        150 non-null    int64
#  12  unit_source_value            0 non-null      float64
# ...

# %%
df.describe(include='all').T
# Out:
#                             count unique  ...          75%          max
# specimen_id                   150    NaN  ...  4.22347e+18   9.1107e+18
# person_id                     150    NaN  ...   6.1287e+18  8.09004e+18
# specimen_concept_id           150    NaN  ...  4.04628e+06  4.35313e+07
# specimen_type_concept_id      150    NaN  ...        32856        32856
# specimen_date                 150    125  ...          NaN          NaN
# specimen_datetime             150    148  ...          NaN          NaN
# quantity                        0    NaN  ...          NaN          NaN
# unit_concept_id                 0    NaN  ...          NaN          NaN
# anatomic_site_concept_id      150    NaN  ...            0            0
# disease_status_concept_id     150    NaN  ...            0            0
# specimen_source_id            150    150  ...          NaN          NaN
# specimen_source_value         150    NaN  ...        70079        70090
# ...

# %% [markdown]
# ##Visit_detail

# %%
df = pd.read_csv(path+"visit_detail.csv")

# %%
df.head()
# Out:
#        visit_detail_id  ...  visit_occurrence_id
# 0 -1757828362327778468  ... -9127810274408915712
# 1 -4357165027259445573  ... -9127810274408915712
# 2  8055254568125344353  ... -9127810274408915712
# 3 -9202240471022785074  ...  3736965967695233281
# 4 -3849978153133518996  ...  3736965967695233281
#
# [5 rows x 19 columns]

# %%
df.shape
# Out:
# (14479, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14479 entries, 0 to 14478
# Data columns (total 19 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   visit_detail_id                 14479 non-null  int64
#  1   person_id                       14479 non-null  int64
#  2   visit_detail_concept_id         14479 non-null  int64
#  3   visit_detail_start_date         14479 non-null  object
#  4   visit_detail_start_datetime     14479 non-null  object
#  5   visit_detail_end_date           14479 non-null  object
#  6   visit_detail_end_datetime       14479 non-null  object
#  7   visit_detail_type_concept_id    14479 non-null  int64
#  8   provider_id                     0 non-null      float64
#  9   care_site_id                    825 non-null    float64
#  10  admitting_source_concept_id     14466 non-null  float64
#  11  discharge_to_concept_id         14370 non-null  float64
# ...

# %%
df.describe(include='all').T
# Out:
#                                 count unique  ...          75%          max
# visit_detail_id                 14479    NaN  ...  4.69993e+18  9.22198e+18
# person_id                       14479    NaN  ...  2.28888e+18  8.80548e+18
# visit_detail_concept_id         14479    NaN  ...  3.80042e+07  4.04814e+07
# visit_detail_start_date         14479    631  ...          NaN          NaN
# visit_detail_start_datetime     14479   1805  ...          NaN          NaN
# visit_detail_end_date           14479    802  ...          NaN          NaN
# visit_detail_end_datetime       14479   1977  ...          NaN          NaN
# visit_detail_type_concept_id    14479    NaN  ...        32817        32817
# provider_id                         0    NaN  ...          NaN          NaN
# care_site_id                      825    NaN  ...  6.88808e+18  9.16353e+18
# admitting_source_concept_id     14466    NaN  ...  3.80042e+07  4.04814e+07
# ...

# %%
import os
files = os.listdir("physionet.org/files/mimic-iv-demo-omop/0.9/1_omop_data_csv")

# %%
for f in files:
  df = pd.read_csv(path+f)
  print(f)
  print(df.info())
  print(df.head())
  print("")
# Out:
# drug_exposure.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18229 entries, 0 to 18228
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   drug_exposure_id              18229 non-null  int64
#  1   person_id                     18229 non-null  int64
#  2   drug_concept_id               18229 non-null  int64
#  3   drug_exposure_start_date      18229 non-null  object
#  4   drug_exposure_start_datetime  18229 non-null  object
#  5   drug_exposure_end_date        18229 non-null  object
#  6   drug_exposure_end_datetime    18229 non-null  object
#  7   verbatim_end_date             0 non-null      float64
#  8   drug_type_concept_id          18229 non-null  int64
#  9   stop_reason                   0 non-null      float64
#  10  refills                       0 non-null      float64
#  11  quantity                      18220 non-null  float64
# ...
